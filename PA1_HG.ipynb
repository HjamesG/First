# %% [markdown]
# * Harrison Gilbert
# * Assignment 1
# * Version 1
# * Fall 2023

# %% [markdown]
# # Harrison Gilbert
# ### Hello! My name is Harrison Gilbert, and I like coding. In my free time I enjoy swimming and reading.
#
# * Programming assignments
# * Quizzes
# * Attendence/In class completed notebook submission
# * Midterm Exam (2)
# * Project (2)
#
# 1. Course Introduction
# 2. Variables and simple data types
# 3. Introducing Lists, Tuples
# 4. List tuples cont.
# 5. If Statements
# 6. Dictionaries
# 7. Loops
# 8. Loops cont.
# 9. Fucntions
# 10. Classes
# 11. Numpy
# 12. Numpy for data analysis
# 13. project 2 discussion
# 14. topics presentation
# 15. Midterm 2
# 16. Final project presentation
#
#
# **I WILL LEARN PYTHON**
#
# *JUPYTER NOTEBOOK from ANACONDA PYTHON is the software I will use*
#
# `Coding` is so fun!
#
# <a href="https://github.com/HjamesG">My GitHub Account</a>
#
# ![words](data:image/png;base64,...)
#
#
#
#
# I learned how to use block code.
